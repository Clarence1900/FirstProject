# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from datetime import datetime
# import re

# %%
with sqlite3.connect('../Compressed/amazon-fine-food-reviews/database.sqlite') as con:
    print ("Opened database successfully")
    df = pd.read_sql_query('SELECT * FROM Reviews', con = con)
    columns = pd.read_sql_query('PRAGMA table_info(Reviews)', con = con)
    print(columns)
df.describe()
# Out:
# Opened database successfully
#    cid                    name     type  notnull dflt_value  pk
# 0    0                      Id  INTEGER        0       None   1
# 1    1               ProductId     TEXT        0       None   0
# 2    2                  UserId     TEXT        0       None   0
# 3    3             ProfileName     TEXT        0       None   0
# 4    4    HelpfulnessNumerator  INTEGER        0       None   0
# 5    5  HelpfulnessDenominator  INTEGER        0       None   0
# 6    6                   Score  INTEGER        0       None   0
# 7    7                    Time  INTEGER        0       None   0
# 8    8                 Summary     TEXT        0       None   0
# 9    9                    Text     TEXT        0       None   0
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %%
df.shape
# Out:
# (568454, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
# Id                        568454 non-null int64
# ProductId                 568454 non-null object
# UserId                    568454 non-null object
# ProfileName               568454 non-null object
# HelpfulnessNumerator      568454 non-null int64
# HelpfulnessDenominator    568454 non-null int64
# Score                     568454 non-null int64
# Time                      568454 non-null int64
# Summary                   568454 non-null object
# Text                      568454 non-null object
# dtypes: int64(5), object(5)
# memory usage: 32.5+ MB

# %%
def changeDateFormat(Time):
    reviewDate = []
    for time in Time:
        dt = datetime.fromtimestamp(time)
        date = dt.strftime("%Y-%m-%d")
        reviewDate.append(date)
    dateSer = pd.Series(reviewDate)
    return dateSer
time = df.loc[:, 'Time']
dateSer = changeDateFormat(time)
df.loc[:, 'Time'] = dateSer

# %%
df.loc[:, 'Time'] = pd.to_datetime(df.loc[:, 'Time'],
                                    format = '%Y-%m-%d',
                                    errors= 'coerce')
df = df.dropna(subset = ['Time'])

# %%
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 0                     1                       1      5 2011-04-27
# 1                     0                       0      1 2012-09-07
# 2                     1                       1      4 2008-08-18
# 3                     3                       3      2 2011-06-13
# 4                     0                       0      5 2012-10-21
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
RateMsg = df.loc[:,['ProductId', 'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score', 'Time']]
RateMsg.head()
# Out:
#     ProductId  HelpfulnessNumerator  HelpfulnessDenominator  Score       Time
# 0  B001E4KFG0                     1                       1      5 2011-04-27
# 1  B00813GRG4                     0                       0      1 2012-09-07
# 2  B000LQOCH0                     1                       1      4 2008-08-18
# 3  B000UA0QIQ                     3                       3      2 2011-06-13
# 4  B006K2ZZ7K                     0                       0      5 2012-10-21

# %%
ReviewCount = RateMsg['ProductId'].value_counts()
ReviewCount.head()
# Out:
# B007JFMH8M    913
# B002QWP8H0    632
# B002QWHJOU    632
# B002QWP89S    632
# B0026RQTGE    632
# Name: ProductId, dtype: int64

# %%
Score = ProductRate = RateMsg.groupby('ProductId')['Score'].mean()

# %%
ProductRate.head()
# Out:
# ProductId
# 0006641040    4.351351
# 141278509X    5.000000
# 2734888454    3.500000
# 2841233731    5.000000
# 7310172001    4.751445
# Name: Score, dtype: float64

# %%
ProductRate.tail()
# Out:
# ProductId
# B009UOFTUI    1.0
# B009UOFU20    1.0
# B009UUS05I    5.0
# B009WSNWC4    5.0
# B009WVB40S    5.0
# Name: Score, dtype: float64

# %%
ProductRate.sort_values(ascending=False).head()
# Out:
# ProductId
# B009WVB40S    5.0
# B0022N49KU    5.0
# B0022N6OBM    5.0
# B0022N6CH8    5.0
# B0022N6CFU    5.0
# Name: Score, dtype: float64

# %%
ProductRate['7310172001']
# Out:
# 4.7514450867052025

# %%
np.percentile(ProductRate,25)
# Out:
# 3.7837837837837838

# %%
np.percentile(ProductRate,50)
# Out:
# 4.5

# %%
np.percentile(ProductRate,75)
# Out:
# 5.0

# %%
RateMsg.groupby('Score')['HelpfulnessNumerator'].sum()
# Out:
# Score
# 1    142964
# 2     55341
# 3     72529
# 4    112134
# 5    608312
# Name: HelpfulnessNumerator, dtype: int64

# %%
RateMsg.groupby('Score')['HelpfulnessDenominator'].sum()
# Out:
# Score
# 1    254536
# 2     92365
# 3    105167
# 4    134378
# 5    680530
# Name: HelpfulnessDenominator, dtype: int64

# %%
HelpfulnessDenominator = RateMsg.groupby('ProductId')['HelpfulnessDenominator'].sum()

# %%
HelpfulnessNumerator = RateMsg.groupby('ProductId')['HelpfulnessNumerator'].sum()

# %%
RateResult = pd.DataFrame(columns=[])

# %%
RateResult['Score'] = Score

# %%
RateResult['HelpfulnessNumerator'] = HelpfulnessNumerator

# %%
RateResult['HelpfulnessDenominator'] = HelpfulnessDenominator

# %%
RateResult['ReviewCount'] = ReviewCount

# %%
type(RateResult)
# Out:
# pandas.core.frame.DataFrame

# %%
RateResult.head()
# Out:
#                Score  HelpfulnessNumerator  HelpfulnessDenominator  \
# ProductId
# 0006641040  4.351351                   112                     125
# 141278509X  5.000000                     1                       1
# 2734888454  3.500000                     1                       1
# 2841233731  5.000000                     0                       0
# 7310172001  4.751445                   140                     211
#
#             ReviewCount
# ProductId
# 0006641040           37
# 141278509X            1
# 2734888454            2
# 2841233731            1
# 7310172001          173

# %%
RateResult.tail()
# Out:
#             Score  HelpfulnessNumerator  HelpfulnessDenominator  ReviewCount
# ProductId
# B009UOFTUI    1.0                     0                       0            1
# B009UOFU20    1.0                     0                       0            1
# B009UUS05I    5.0                     0                       0            1
# B009WSNWC4    5.0                     0                       0            1
# B009WVB40S    5.0                     0                       0            1

# %%
RateMsg.loc[RateMsg['ProductId'] == '0006641040']
# Out:
#          ProductId  HelpfulnessNumerator  HelpfulnessDenominator  Score  \
# 150492  0006641040                    71                      72      4
# 150493  0006641040                     3                       3      5
# 150494  0006641040                     3                       3      3
# 150495  0006641040                     3                       3      5
# 150496  0006641040                     2                       2      1
# 150497  0006641040                     2                       2      5
# 150498  0006641040                     2                       2      5
# 150499  0006641040                     2                       2      5
# 150500  0006641040                     2                       2      5
# 150501  0006641040                     1                       1      4
# 150502  0006641040                     1                       1      5
# 150503  0006641040                     1                       1      4
# 150504  0006641040                     1                       1      4
# 150505  0006641040                     1                       1      4
# 150506  0006641040                     1                       1      4
# 150507  0006641040                     1                       1      5
# 150508  0006641040                     3                       4      5
# 150509  0006641040                     0                       0      5
# 150510  0006641040                     0                       0      4
# 150511  0006641040                     0                       0      5
# 150512  0006641040                     0                       0      5
# 150513  0006641040                     0                       0      5
# 150514  0006641040                     0                       0      5
# 150515  0006641040                     0                       0      5
# 150516  0006641040                     0                       0      5
# 150517  0006641040                     0                       0      5
# 150518  0006641040                     0                       0      5
# 150519  0006641040                     0                       0      5
# 150520  0006641040                     0                       0      5
# 150521  0006641040                     0                       0      4
# 150522  0006641040                     0                       0      4
# 150523  0006641040                     0                       0      5
# 150524  0006641040                     1                       2      5
# 150525  0006641040                    11                      18      1
# 150526  0006641040                     0                       1      3
# 150527  0006641040                     0                       1      3
# 150528  0006641040                     0                       1      4
#
#              Time
# 150492 2004-09-29
# 150493 2007-03-08
# 150494 2005-10-17
# 150495 2005-03-21
# 150496 2012-04-18
# 150497 2007-04-12
# 150498 2003-10-11
# 150499 2001-12-26
# 150500 1999-10-25
# 150501 2011-12-27
# 150502 2009-02-07
# 150503 2008-06-01
# 150504 2008-05-15
# 150505 2007-11-11
# 150506 2007-10-04
# 150507 2004-02-06
# 150508 2002-04-10
# 150509 2012-09-23
# 150510 2012-08-06
# 150511 2012-05-29
# 150512 2012-01-05
# 150513 2011-08-21
# 150514 2011-04-19
# 150515 2011-01-01
# 150516 2010-11-30
# 150517 2010-10-28
# 150518 2009-10-29
# 150519 2009-10-28
# 150520 2009-05-28
# 150521 2008-08-24
# 150522 2004-10-02
# 150523 1999-10-08
# 150524 2002-07-01
# 150525 2005-10-17
# 150526 2011-12-14
# 150527 2011-02-05
# 150528 2005-02-15

# %%
RateResult.sort_values('Score', ascending=False)
# Out:
#             Score  HelpfulnessNumerator  HelpfulnessDenominator  ReviewCount
# ProductId
# B00214BO58    5.0                     0                       0            2
# B002PDYN44    5.0                     1                       1            1
# B002P9QAJE    5.0                     0                       0            2
# B002P9QRCO    5.0                     0                       0            1
# B002PA1KW0    5.0                     2                       3            1
# B002PA7466    5.0                     0                       0            1
# B002PAHIWQ    5.0                     1                       2            1
# B002PAJFGS    5.0                     4                       4            1
# B002PALD4K    5.0                     2                       3            2
# B002PANI1G    5.0                    16                      16            4
# B002PE15WG    5.0                     0                       0            1
# B002P9ETUQ    5.0                     0                       0            1
# B002PE6E0Y    5.0                     1                       2            1
# B002PEYJSI    5.0                     2                       2            3
# B002PEYJW4    5.0                     0                       0            1
# B002PEYJZ6    5.0                     0                       0            1
# B002PF1UG6    5.0                     0                       0            1
# B002PHOHZ0    5.0                     8                       8            4
# B002PHQJWE    5.0                     0                       0            1
# B002PHUHXG    5.0                     0                       0            1
# B002P9OKSM    5.0                     0                       0            1
# B002P9D3GC    5.0                     3                       4            2
# B002T9J5XI    5.0                     0                       0            1
# B002OXLXLG    5.0                     0                       0            1
# B002OUQI6O    5.0                     2                       2            1
# B002OVC39E    5.0                     1                       1            1
# B002OVE7JS    5.0                     2                       2            1
# B002OW55CA    5.0                     6                       6            4
# B002OWISNI    5.0                     1                       1            1
# B002OXEVNS    5.0                     0                       0            1
# ...           ...                   ...                     ...          ...
# B005FRCC6S    1.0                     0                       0            1
# B000I1PKCE    1.0                     2                       2            1
# B003F87WDC    1.0                     0                       0            1
# B005FP74HM    1.0                     0                       0            1
# B0006342KK    1.0                     3                       6            1
# B003EMXOR2    1.0                     0                       0            1
# B005GRBD08    1.0                     0                       0            1
# B005GWYI3W    1.0                     0                       0            2
# B005GTV7PM    1.0                     0                       0            1
# B003EMSMJW    1.0                     4                       4            1
# B005GWUPTI    1.0                     0                       0            1
# B00061I7DU    1.0                     0                       4            1
# B005GWTTR2    1.0                     0                       0            2
# B0029NN9ZE    1.0                     2                      11            1
# B005GWTNJG    1.0                     0                       1            1
# B005GWTMEW    1.0                     0                       0            1
# B005GTVLG2    1.0                     0                       0            1
# B005GTVHQ6    1.0                     0                       0            1
# B000UY0JJI    1.0                     0                       0            1
# B005GRBO7K    1.0                     0                       0            2
# B00061MUH4    1.0                     0                       0            1
# B005GTULQ8    1.0                     0                       0            1
# B005GTUGZO    1.0                     0                       0            1
# B005GTUDZM    1.0                     0                       1            1
# B00061MWKO    1.0                     3                       3            1
# B003EMVVP4    1.0                     0                       1            1
# B005GSSI0U    1.0                     2                       2            1
# B003EMVXWK    1.0                     0                       0            1
# B003EMW37O    1.0                     0                       6            1
# B001EO601O    1.0                     0                       0            1
#
# [74258 rows x 4 columns]

# %%
RateResult.sort_values('ReviewCount', ascending=False)
# Out:
#                Score  HelpfulnessNumerator  HelpfulnessDenominator  \
# ProductId
# B007JFMH8M  4.582694                    41                      46
# B0026RQTGE  4.588608                   611                     887
# B002QWHJOU  4.588608                   611                     887
# B002QWP89S  4.588608                   611                     887
# B002QWP8H0  4.588608                   611                     887
# B003B3OOPA  4.739968                  2944                    3415
# B001EO5Q64  4.746032                  1947                    2340
# B0026KPDG8  4.310284                   488                     705
# B000VK8AVK  4.310284                   488                     705
# B006HYLW32  4.310284                   488                     705
# B007M83302  4.310284                   488                     705
# B007M832YY  4.310284                   488                     705
# B001RVFEP2  4.310284                   488                     705
# B001RVFERK  4.310284                   488                     705
# B0026KNQSA  4.310284                   488                     705
# B0013NUGDE  4.310284                   488                     705
# B000KV7ZGQ  3.411871                  1012                    1189
# B000KV61FC  3.411871                  1012                    1189
# B0013A0QXC  4.343173                   445                     568
# B005K4Q1YA  3.819188                   797                    1066
# B000NMJWZO  4.881919                   711                     850
# B005K4Q34S  3.819188                   797                    1066
# B005K4Q37A  3.819188                   797                    1066
# B000UBD88A  4.343173                   445                     568
# B005K4Q4LK  3.819188                   797                    1066
# B003GTR8IO  3.813208                   213                     383
# B0090X8IPM  3.813208                   213                     383
# B007Y59HVM  4.363636                   988                    1395
# B005ZBZLT4  4.363636                   988                    1395
# B006MONQMC  3.380855                   197                     481
# ...              ...                   ...                     ...
# B003YVN6WG  1.000000                     0                       0
# B003YZ3M8U  1.000000                     0                       0
# B000YOAK2K  4.000000                     0                       0
# B000YOMRA8  5.000000                     0                       0
# B003YYZT7I  5.000000                     0                       0
# B000YPD6E8  5.000000                     0                       0
# B000YPIIYQ  2.000000                     1                       1
# B003YWDL16  5.000000                     1                       1
# B003YVSIB0  4.000000                     0                       0
# B000YPKOIY  3.000000                     1                       1
# B000YPKPE2  2.000000                     1                       1
# B003YVPXWM  5.000000                     0                       0
# B003YVNKKE  5.000000                     0                       0
# B003YVN914  2.000000                     0                       0
# B000YPMKAY  5.000000                     0                       0
# B000YQE6HS  4.000000                     0                       0
# B003YV7Z4G  5.000000                     0                       0
# B003YV7Z3W  5.000000                     0                       0
# B000YPO6GU  5.000000                     0                       0
# B000YPO6II  5.000000                     0                       0
# B003YUVD68  5.000000                     5                       5
# B003YUVD2M  5.000000                     1                       1
# B003YUTDRE  5.000000                     1                       1
# B000YPO73M  1.000000                     0                       1
# B003YU7V1E  5.000000                     1                       1
# B000YPQC08  5.000000                     0                       0
# B003YU5T6I  5.000000                     0                       0
# B000YPQC44  5.000000                     0                       0
# B000YPQE6U  5.000000                     1                       1
# B009WVB40S  5.000000                     0                       0
#
#             ReviewCount
# ProductId
# B007JFMH8M          913
# B0026RQTGE          632
# B002QWHJOU          632
# B002QWP89S          632
# B002QWP8H0          632
# B003B3OOPA          623
# B001EO5Q64          567
# B0026KPDG8          564
# B000VK8AVK          564
# B006HYLW32          564
# B007M83302          564
# B007M832YY          564
# B001RVFEP2          564
# B001RVFERK          564
# B0026KNQSA          564
# B0013NUGDE          564
# B000KV7ZGQ          556
# B000KV61FC          556
# B0013A0QXC          542
# B005K4Q1YA          542
# B000NMJWZO          542
# B005K4Q34S          542
# B005K4Q37A          542
# B000UBD88A          542
# B005K4Q4LK          542
# B003GTR8IO          530
# B0090X8IPM          530
# B007Y59HVM          506
# B005ZBZLT4          506
# B006MONQMC          491
# ...                 ...
# B003YVN6WG            1
# B003YZ3M8U            1
# B000YOAK2K            1
# B000YOMRA8            1
# B003YYZT7I            1
# B000YPD6E8            1
# B000YPIIYQ            1
# B003YWDL16            1
# B003YVSIB0            1
# B000YPKOIY            1
# B000YPKPE2            1
# B003YVPXWM            1
# B003YVNKKE            1
# B003YVN914            1
# B000YPMKAY            1
# B000YQE6HS            1
# B003YV7Z4G            1
# B003YV7Z3W            1
# B000YPO6GU            1
# B000YPO6II            1
# B003YUVD68            1
# B003YUVD2M            1
# B003YUTDRE            1
# B000YPO73M            1
# B003YU7V1E            1
# B000YPQC08            1
# B003YU5T6I            1
# B000YPQC44            1
# B000YPQE6U            1
# B009WVB40S            1
#
# [74258 rows x 4 columns]

# %%
RateResult.sort_values('HelpfulnessDenominator', ascending=False)
# Out:
#                Score  HelpfulnessNumerator  HelpfulnessDenominator  \
# ProductId
# B00012182G  3.582677                  3989                    5462
# B000FI4O90  3.894737                  3535                    3894
# B003B3OOPA  4.739968                  2944                    3415
# B000VK08OC  4.491379                  2630                    2963
# B001EO5Q64  4.746032                  1947                    2340
# B004WTHCO2  3.679487                  2074                    2329
# B001LQCOIS  3.679487                  2074                    2329
# B00032G1S0  4.200000                  2074                    2142
# B000FFLHU2  3.940678                  1666                    1918
# B004CLCEDE  3.509259                  1581                    1808
# B004EAGP74  4.802057                  1517                    1777
# B001E8DHPW  4.802057                  1517                    1777
# B000GAT6NG  4.802057                  1517                    1777
# B005FKRTO0  4.900000                  1739                    1760
# B00859FH7O  4.900000                  1739                    1760
# B0069GOKGE  4.900000                  1739                    1760
# B005F3IAPE  4.900000                  1739                    1760
# B008F2K1YU  4.900000                  1739                    1760
# B0051SU0OW  4.900000                  1739                    1760
# B009K2BBQG  4.900000                  1739                    1760
# B008VQ01Y0  4.900000                  1739                    1760
# B009K2BBT8  4.900000                  1739                    1760
# B0065G59F4  4.900000                  1739                    1760
# B001EO5U3I  4.682584                  1394                    1665
# B008J1HO4C  4.682584                  1394                    1665
# B00507A02Q  2.841270                  1046                    1643
# B000OQ2DJQ  4.607306                  1318                    1640
# B000OQ2DL4  4.607306                  1318                    1640
# B00125ZCWI  4.607306                  1318                    1640
# B0019QT66I  4.607306                  1318                    1640
# ...              ...                   ...                     ...
# B002VO7J98  5.000000                     0                       0
# B002VP570K  5.000000                     0                       0
# B002WF77B6  4.000000                     0                       0
# B002WF5M2M  1.000000                     0                       0
# B002WET2XS  5.000000                     0                       0
# B002WEF0FM  5.000000                     0                       0
# B002WDK34Q  5.000000                     0                       0
# B002WDISF2  5.000000                     0                       0
# B002WDIS2K  2.000000                     0                       0
# B002WBTY3Y  3.000000                     0                       0
# B002WAITQ8  4.500000                     0                       0
# B002W9JIHS  1.000000                     0                       0
# B002W9C9EM  5.000000                     0                       0
# B002W9BK10  5.000000                     0                       0
# B002W90JJY  5.000000                     0                       0
# B002W8ONRY  5.000000                     0                       0
# B002W8LMH8  4.000000                     0                       0
# B002W5OA8Y  5.000000                     0                       0
# B002W51EWY  5.000000                     0                       0
# B002W51EU6  4.000000                     0                       0
# B002W4DLJE  5.000000                     0                       0
# B002W1D89U  5.000000                     0                       0
# B002VZWG22  5.000000                     0                       0
# B002VZWCBM  5.000000                     0                       0
# B002VXFCDY  1.000000                     0                       0
# B002VX3E70  4.000000                     0                       0
# B002VUAM32  4.000000                     0                       0
# B002VT3CY4  3.000000                     0                       0
# B002VRQJC8  5.000000                     0                       0
# B009WVB40S  5.000000                     0                       0
#
#             ReviewCount
# ProductId
# B00012182G          127
# B000FI4O90          190
# B003B3OOPA          623
# B000VK08OC          232
# B001EO5Q64          567
# B004WTHCO2          234
# B001LQCOIS          234
# B00032G1S0           10
# B000FFLHU2          118
# B004CLCEDE          324
# B004EAGP74          389
# B001E8DHPW          389
# B000GAT6NG          389
# B005FKRTO0           10
# B00859FH7O           10
# B0069GOKGE           10
# B005F3IAPE           10
# B008F2K1YU           10
# B0051SU0OW           10
# B009K2BBQG           10
# B008VQ01Y0           10
# B009K2BBT8           10
# B0065G59F4           10
# B001EO5U3I          356
# B008J1HO4C          356
# B00507A02Q          126
# B000OQ2DJQ          219
# B000OQ2DL4          219
# B00125ZCWI          219
# B0019QT66I          219
# ...                 ...
# B002VO7J98            1
# B002VP570K            1
# B002WF77B6            1
# B002WF5M2M            1
# B002WET2XS            1
# B002WEF0FM            1
# B002WDK34Q            1
# B002WDISF2            1
# B002WDIS2K            1
# B002WBTY3Y            1
# B002WAITQ8            2
# B002W9JIHS            1
# B002W9C9EM            1
# B002W9BK10            1
# B002W90JJY            1
# B002W8ONRY            1
# B002W8LMH8            1
# B002W5OA8Y            1
# B002W51EWY            1
# B002W51EU6            3
# B002W4DLJE            4
# B002W1D89U            1
# B002VZWG22            1
# B002VZWCBM            1
# B002VXFCDY            1
# B002VX3E70            1
# B002VUAM32            2
# B002VT3CY4            1
# B002VRQJC8            2
# B009WVB40S            1
#
# [74258 rows x 4 columns]

# %%
RateResult.sort_values('HelpfulnessNumerator', ascending=False)
# Out:
#                Score  HelpfulnessNumerator  HelpfulnessDenominator  \
# ProductId
# B00012182G  3.582677                  3989                    5462
# B000FI4O90  3.894737                  3535                    3894
# B003B3OOPA  4.739968                  2944                    3415
# B000VK08OC  4.491379                  2630                    2963
# B004WTHCO2  3.679487                  2074                    2329
# B00032G1S0  4.200000                  2074                    2142
# B001LQCOIS  3.679487                  2074                    2329
# B001EO5Q64  4.746032                  1947                    2340
# B008F2K1YU  4.900000                  1739                    1760
# B0051SU0OW  4.900000                  1739                    1760
# B008VQ01Y0  4.900000                  1739                    1760
# B0069GOKGE  4.900000                  1739                    1760
# B005FKRTO0  4.900000                  1739                    1760
# B009K2BBQG  4.900000                  1739                    1760
# B009K2BBT8  4.900000                  1739                    1760
# B00859FH7O  4.900000                  1739                    1760
# B005F3IAPE  4.900000                  1739                    1760
# B0065G59F4  4.900000                  1739                    1760
# B000FFLHU2  3.940678                  1666                    1918
# B004CLCEDE  3.509259                  1581                    1808
# B000GAT6NG  4.802057                  1517                    1777
# B001E8DHPW  4.802057                  1517                    1777
# B004EAGP74  4.802057                  1517                    1777
# B001EO5U3I  4.682584                  1394                    1665
# B008J1HO4C  4.682584                  1394                    1665
# B0099HD3YA  2.117647                  1387                    1498
# B005K0L2U2  4.500000                  1375                    1426
# B005QOLSJ2  4.500000                  1375                    1426
# B000OQ2DJQ  4.607306                  1318                    1640
# B003SSWCJI  4.607306                  1318                    1640
# ...              ...                   ...                     ...
# B002PNNNHC  5.000000                     0                       0
# B002PMQFLO  5.000000                     0                       0
# B002PM0538  4.000000                     0                       0
# B002PKZIBE  5.000000                     0                       0
# B002PJVPNU  4.333333                     0                       1
# B002PJSCQS  5.000000                     0                       0
# B002PJETZG  5.000000                     0                       0
# B002PJAZV8  2.000000                     0                       6
# B002PJAZEU  5.000000                     0                       0
# B002PHUHZO  5.000000                     0                       0
# B002PHUHXG  5.000000                     0                       0
# B002PHQJWE  5.000000                     0                       0
# B002PF1UG6  5.000000                     0                       0
# B002PEYJW4  5.000000                     0                       0
# B002P2V7BW  5.000000                     0                       0
# B002PEUZC2  3.000000                     0                       1
# B002PE1DZU  4.000000                     0                       0
# B002PE15WG  5.000000                     0                       0
# B002PAYL80  4.000000                     0                       0
# B002PAAWQU  4.666667                     0                       0
# B002PA7466  5.000000                     0                       0
# B002P9QRCO  5.000000                     0                       0
# B002P9QAJE  5.000000                     0                       0
# B002P9OKSM  5.000000                     0                       0
# B002P9ETUQ  5.000000                     0                       0
# B002P99DOI  3.000000                     0                       0
# B002P5E1EE  5.000000                     0                       0
# B002P5D37K  5.000000                     0                       0
# B002P323DC  1.000000                     0                       0
# B009WVB40S  5.000000                     0                       0
#
#             ReviewCount
# ProductId
# B00012182G          127
# B000FI4O90          190
# B003B3OOPA          623
# B000VK08OC          232
# B004WTHCO2          234
# B00032G1S0           10
# B001LQCOIS          234
# B001EO5Q64          567
# B008F2K1YU           10
# B0051SU0OW           10
# B008VQ01Y0           10
# B0069GOKGE           10
# B005FKRTO0           10
# B009K2BBQG           10
# B009K2BBT8           10
# B00859FH7O           10
# B005F3IAPE           10
# B0065G59F4           10
# B000FFLHU2          118
# B004CLCEDE          324
# B000GAT6NG          389
# B001E8DHPW          389
# B004EAGP74          389
# B001EO5U3I          356
# B008J1HO4C          356
# B0099HD3YA           34
# B005K0L2U2           10
# B005QOLSJ2           10
# B000OQ2DJQ          219
# B003SSWCJI          219
# ...                 ...
# B002PNNNHC            1
# B002PMQFLO            1
# B002PM0538            1
# B002PKZIBE            1
# B002PJVPNU            3
# B002PJSCQS            1
# B002PJETZG            1
# B002PJAZV8            2
# B002PJAZEU            1
# B002PHUHZO            1
# B002PHUHXG            1
# B002PHQJWE            1
# B002PF1UG6            1
# B002PEYJW4            1
# B002P2V7BW            1
# B002PEUZC2            1
# B002PE1DZU            1
# B002PE15WG            1
# B002PAYL80            1
# B002PAAWQU            3
# B002PA7466            1
# B002P9QRCO            1
# B002P9QAJE            2
# B002P9OKSM            1
# B002P9ETUQ            1
# B002P99DOI            2
# B002P5E1EE            1
# B002P5D37K            1
# B002P323DC            1
# B009WVB40S            1
#
# [74258 rows x 4 columns]

# %%
Y1 = [0,0,0,0]

# %%
Y1[3] = RateResult.loc[RateResult['Score'] >= 4, 'HelpfulnessNumerator'].sum()

# %%
Y1[2] = RateResult.loc[(RateResult.Score >= 3) & (RateResult.Score <= 4), 'HelpfulnessNumerator'].sum()

# %%
Y1[1] = RateResult.loc[(RateResult.Score >= 2) & (RateResult.Score <= 3), 'HelpfulnessNumerator'].sum()

# %%
Y1[0] = RateResult.loc[RateResult['Score'] <= 2, 'HelpfulnessNumerator'].sum()

# %%
Y2 = [0,0,0,0]

# %%
Y2[3] = RateResult.loc[RateResult['Score'] >= 4, 'HelpfulnessDenominator'].sum()

# %%
Y2[2] = RateResult.loc[(RateResult.Score >= 3) & (RateResult.Score <= 4), 'HelpfulnessDenominator'].sum()

# %%
Y2[1] = RateResult.loc[(RateResult.Score >= 2) & (RateResult.Score <= 3), 'HelpfulnessDenominator'].sum()

# %%
Y2[0] = RateResult.loc[RateResult['Score'] <= 2, 'HelpfulnessDenominator'].sum()

# %%
RateResult.loc[RateResult['Score'] >= 4, 'ReviewCount'].sum()
# Out:
# 406188

# %%
RateResult.loc[(RateResult.Score >= 3) & (RateResult.Score <= 4), 'ReviewCount'].sum()
# Out:
# 161912

# %%
RateResult.loc[(RateResult.Score >= 2) & (RateResult.Score <= 3), 'ReviewCount'].sum()
# Out:
# 23735

# %%
RateResult.loc[RateResult['Score'] <= 2, 'ReviewCount'].sum()
# Out:
# 8710

# %%
X = ['1-2', '2-3', '3-4', '4-5']
Y1 = np.array(Y1)
Y2 = np.array(Y2)
plot.bar(X, +Y1)
plot.bar(X, -Y2)
plot.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plot.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
plot.show()

# %%
print('Y1:', Y1, '\n', 'Y1:', Y2)
# Out:
# Y1: [ 16457  46426 285613 685037]
#  Y1: [ 22426  65183 387211 851435]
